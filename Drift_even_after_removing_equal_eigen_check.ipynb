# %%
import pickle
import tensorflow as tf
import numpy as np
fid = open('smith.pkl','rb')
#x0 = pickle.load(fid)
x1 = pickle.load(fid)
x2 = pickle.load(fid)
fid.close()

# %%
#for ii in x0:
#    print(ii)

for ii in x1:
    print(ii)

for ii in x2:
    print(ii)
# Out:
# iterations
# learning_rate
# loss
# iterations
# drift_dict_layer1/dhmul/Dfreq_real:0

# %%
import matplotlib
import matplotlib.pyplot
# %matplotlib inline

matplotlib.pyplot.plot(x1['learning_rate'],x1['loss'])
matplotlib.pyplot.show()

# %%
matplotlib.pyplot.plot(x2['iterations'][50:],x2['drift_dict_layer1/dhmul/Dfreq_real:0'][50:])
matplotlib.pyplot.show()

# %%
import pickle
import tensorflow as tf
import numpy as np
fid = open('ML_LRA_times.pkl','rb')
#x0 = pickle.load(fid)
x1 = pickle.load(fid)
x2 = pickle.load(fid)
fid.close()

# %%
for ii in x1:
    print(ii)

for ii in x2:
    print(ii)
# Out:
# iterations
# drift_dict_layer1/dhmul/Dfreq_real:0
# 967.5982944965363
# 772.5404794216156
# 773.4846062660217
# 772.986575126648
# 771.9276037216187
# 773.9296000003815
# 775.5508370399475
# 776.4991164207458

# %%
import matplotlib
import matplotlib.pyplot
# %matplotlib inline
matplotlib.pyplot.plot(x1['iterations'][0:499],x1['drift_dict_layer1/dhmul/Dfreq_real:0'][0:499])
matplotlib.pyplot.xlabel('iteration')
matplotlib.pyplot.ylabel('drift')
matplotlib.pyplot.title('Expected and Desired Behavior\n Observed for Many Iterations')
matplotlib.pyplot.show()

# %%
import matplotlib
import matplotlib.pyplot
# %matplotlib inline
matplotlib.pyplot.plot(x1['iterations'][492:508],x1['drift_dict_layer1/dhmul/Dfreq_real:0'][492:508])
matplotlib.pyplot.xlabel('iteration')
matplotlib.pyplot.ylabel('drift')
matplotlib.pyplot.title('Observed Weird Jump, Not a Big Deal')
matplotlib.pyplot.show()

# %%
# %matplotlib inline
matplotlib.pyplot.plot(x1['iterations'][:],x1['drift_dict_layer1/dhmul/Dfreq_real:0'][:])
matplotlib.pyplot.xlabel('iteration')
matplotlib.pyplot.ylabel('drift')
matplotlib.pyplot.title('More Expected Behavior')
matplotlib.pyplot.show()
