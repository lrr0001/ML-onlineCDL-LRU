# %%
import pickle
import tensorflow as tf
fid = open('smith.pkl','rb')
x0 = pickle.load(fid)
x1 = pickle.load(fid)
fid.close()

# %%
for ii in x0:
    print(ii)

for ii in x1:
    print(ii)
# Out:
# iterations
# learning_rate
# loss
# iterations
# drift_dict_layer1/dhmul/Dfreq_real:0

# %%
import matplotlib
import matplotlib.pyplot
# %matplotlib inline

matplotlib.pyplot.plot(x0['learning_rate'],x0['loss'])
matplotlib.pyplot.show()

# %%
matplotlib.pyplot.plot(x1['iterations'][:50],x1['drift_dict_layer1/dhmul/Dfreq_real:0'][:50])
matplotlib.pyplot.show()
