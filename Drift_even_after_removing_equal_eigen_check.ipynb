# %%
import pickle
import tensorflow as tf
import numpy as np
fid = open('smith.pkl','rb')
#x0 = pickle.load(fid)
x1 = pickle.load(fid)
x2 = pickle.load(fid)
fid.close()

# %%
#for ii in x0:
#    print(ii)

for ii in x1:
    print(ii)

for ii in x2:
    print(ii)
# Out:
# iterations
# learning_rate
# loss
# iterations
# drift_dict_layer1/dhmul/Dfreq_real:0

# %%
import matplotlib
import matplotlib.pyplot
# %matplotlib inline

matplotlib.pyplot.plot(x1['learning_rate'],x1['loss'])
matplotlib.pyplot.show()

# %%
matplotlib.pyplot.plot(x2['iterations'][:48],x2['drift_dict_layer1/dhmul/Dfreq_real:0'][:48])
matplotlib.pyplot.show()
